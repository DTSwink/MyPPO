# %% [markdown]
# # MyPPO CleanRL-Style PPO Sweep
#
# Use a GPU runtime. This notebook clones the repo, installs the minimal dependencies, and runs the autonomous PPO sweep with 180-step episodes.

# %%
# !git clone https://github.com/DTSwink/MyPPO.git
# %cd MyPPO
# !pip install -r requirements.txt

# %%
# !python scripts/sweep_ppo.py \
  --output-dir checkpoints/ppo_sweep \
  --max-trials 5 \
  --timesteps-per-trial 25920000 \
  --num-envs 2048 \
  --eval-envs 2048 \
  --target-loss 1e-5

# %%
# !find checkpoints/ppo_sweep -maxdepth 2 -type f | sort
# !cat checkpoints/ppo_sweep/sweep_summary.jsonl || true
